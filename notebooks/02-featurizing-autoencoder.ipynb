# %%
import os
import pandas as pd
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import regularizers

# %%
# Define the root directory of the project as credit-mlops
ROOT_DIR = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
print(ROOT_DIR)
# Out:
# /workspaces/credit-mlops

# %%
# Read the processed data
df = pd.read_csv(os.path.join(ROOT_DIR, 'data', 'processed', 'processed_data.csv'))
df.head(2)
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182       95.4               0.0
# 1  3202.467416           0.909091        0.0               0.0
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                         0.0                          0.083333
# 1                         0.0                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                    0.00                 0              2        1000.0
# 1                    0.25                 4              0        7000.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12

# %% [markdown]
# ## Normalizing data

# %%
from sklearn.preprocessing import StandardScaler

# Create the MinMaxScaler object
scaler = StandardScaler()

# Fit and transform the data
df = scaler.fit_transform(df)

# %% [markdown]
# ## Autoencoder

# %% [markdown]
# ### Implement autoencoder

# %%
# Define the number of features
input_dim = df.shape[1]
encoding_dim = 10

# Define the input layer
input_layer = Input(shape=(input_dim, ))

# Define the encoder layer
encoder_layer = Dense(encoding_dim, activation="tanh", activity_regularizer=regularizers.l1(10e-5))(input_layer)

# Define the decoder layer
decoder_layer = Dense(input_dim, activation="relu")(encoder_layer)

# Define the autoencoder model
autoencoder = Model(inputs=input_layer, outputs=decoder_layer)

# Compile the autoencoder model
autoencoder.compile(optimizer='adam', loss='mean_squared_error')

# Define the early stopping criteria
early_stopping = EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=5, verbose=1, mode='min', restore_best_weights=True)

# Train the autoencoder model
autoencoder.fit(df, df, epochs=100, batch_size=32, shuffle=True, validation_split=0.2, verbose=1, callbacks=[early_stopping])

# Save the autoencoder model
autoencoder.save(os.path.join(ROOT_DIR, 'models', 'autoencoder.pkl'))
# Out:
# Epoch 1/100
# 184/184 [==============================] - 1s 2ms/step - loss: 0.8916 - val_loss: 0.5545
# Epoch 2/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.6524 - val_loss: 0.4521
# Epoch 3/100
# 184/184 [==============================] - 0s 2ms/step - loss: 0.5581 - val_loss: 0.4152
# Epoch 4/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.5065 - val_loss: 0.3942
# Epoch 5/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.4687 - val_loss: 0.3782
# Epoch 6/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.4374 - val_loss: 0.3655
# Epoch 7/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.4112 - val_loss: 0.3545
# Epoch 8/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.3915 - val_loss: 0.3472
# Epoch 9/100
# 184/184 [==============================] - 0s 2ms/step - loss: 0.3760 - val_loss: 0.3416
# Epoch 10/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.3635 - val_loss: 0.3370
# Epoch 11/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.3531 - val_loss: 0.3334
# Epoch 12/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.3441 - val_loss: 0.3303
# Epoch 13/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.3362 - val_loss: 0.3276
# Epoch 14/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.3295 - val_loss: 0.3251
# Epoch 15/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.3236 - val_loss: 0.3232
# Epoch 16/100
# 184/184 [==============================] - 0s 2ms/step - loss: 0.3181 - val_loss: 0.3217
# Epoch 17/100
# 184/184 [==============================] - 0s 2ms/step - loss: 0.3132 - val_loss: 0.3202
# Epoch 18/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.3088 - val_loss: 0.3184
# Epoch 19/100
# 184/184 [==============================] - 0s 2ms/step - loss: 0.3048 - val_loss: 0.3171
# Epoch 20/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.3011 - val_loss: 0.3154
# Epoch 21/100
# 184/184 [==============================] - 0s 2ms/step - loss: 0.2977 - val_loss: 0.3146
# Epoch 22/100
# 184/184 [==============================] - 0s 2ms/step - loss: 0.2944 - val_loss: 0.3133
# Epoch 23/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2914 - val_loss: 0.3127
# Epoch 24/100
# 184/184 [==============================] - 0s 2ms/step - loss: 0.2887 - val_loss: 0.3117
# Epoch 25/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2863 - val_loss: 0.3103
# Epoch 26/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2839 - val_loss: 0.3098
# Epoch 27/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2816 - val_loss: 0.3086
# Epoch 28/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2792 - val_loss: 0.3080
# Epoch 29/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2772 - val_loss: 0.3077
# Epoch 30/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2755 - val_loss: 0.3068
# Epoch 31/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2737 - val_loss: 0.3060
# Epoch 32/100
# 184/184 [==============================] - 0s 2ms/step - loss: 0.2721 - val_loss: 0.3053
# Epoch 33/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2706 - val_loss: 0.3045
# Epoch 34/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2690 - val_loss: 0.3041
# Epoch 35/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2675 - val_loss: 0.3038
# Epoch 36/100
# 184/184 [==============================] - 0s 2ms/step - loss: 0.2664 - val_loss: 0.3036
# Epoch 37/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2649 - val_loss: 0.3028
# Epoch 38/100
# 184/184 [==============================] - 0s 2ms/step - loss: 0.2637 - val_loss: 0.3019
# Epoch 39/100
# 184/184 [==============================] - 0s 2ms/step - loss: 0.2625 - val_loss: 0.3020
# Epoch 40/100
# 184/184 [==============================] - 0s 2ms/step - loss: 0.2614 - val_loss: 0.3010
# Epoch 41/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2604 - val_loss: 0.3009
# Epoch 42/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2592 - val_loss: 0.3004
# Epoch 43/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2583 - val_loss: 0.3000
# Epoch 44/100
# 184/184 [==============================] - 0s 2ms/step - loss: 0.2575 - val_loss: 0.2998
# Epoch 45/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2567 - val_loss: 0.2994
# Epoch 46/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2557 - val_loss: 0.2991
# Epoch 47/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.2549 - val_loss: 0.2986
# Epoch 48/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2541 - val_loss: 0.2979
# Epoch 49/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2533 - val_loss: 0.2973
# Epoch 50/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2523 - val_loss: 0.2980
# Epoch 51/100
# 184/184 [==============================] - 0s 2ms/step - loss: 0.2520 - val_loss: 0.2968
# Epoch 52/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2513 - val_loss: 0.2969
# Epoch 53/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2504 - val_loss: 0.2968
# Epoch 54/100
# 184/184 [==============================] - 0s 2ms/step - loss: 0.2503 - val_loss: 0.2962
# Epoch 55/100
# 184/184 [==============================] - 0s 2ms/step - loss: 0.2495 - val_loss: 0.2961
# Epoch 56/100
# 184/184 [==============================] - 0s 2ms/step - loss: 0.2489 - val_loss: 0.2957
# Epoch 57/100
# 184/184 [==============================] - 0s 2ms/step - loss: 0.2488 - val_loss: 0.2956
# Epoch 58/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2481 - val_loss: 0.2953
# Epoch 59/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2472 - val_loss: 0.2947
# Epoch 60/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2469 - val_loss: 0.2948
# Epoch 61/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2461 - val_loss: 0.2951
# Epoch 62/100
# 184/184 [==============================] - 0s 2ms/step - loss: 0.2460 - val_loss: 0.2941
# Epoch 63/100
# 184/184 [==============================] - 0s 2ms/step - loss: 0.2452 - val_loss: 0.2943
# Epoch 64/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2452 - val_loss: 0.2937
# Epoch 65/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2446 - val_loss: 0.2938
# Epoch 66/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2446 - val_loss: 0.2933
# Epoch 67/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2440 - val_loss: 0.2943
# Epoch 68/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2434 - val_loss: 0.2931
# Epoch 69/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2434 - val_loss: 0.2930
# Epoch 70/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2429 - val_loss: 0.2928
# Epoch 71/100
# 184/184 [==============================] - 0s 2ms/step - loss: 0.2424 - val_loss: 0.2927
# Epoch 72/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2422 - val_loss: 0.2931
# Epoch 73/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2419 - val_loss: 0.2925
# Epoch 74/100
# 184/184 [==============================] - 0s 2ms/step - loss: 0.2417 - val_loss: 0.2921
# Epoch 75/100
# 184/184 [==============================] - 0s 2ms/step - loss: 0.2415 - val_loss: 0.2923
# Epoch 76/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2411 - val_loss: 0.2922
# Epoch 77/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2407 - val_loss: 0.2922
# Epoch 78/100
# 184/184 [==============================] - 0s 2ms/step - loss: 0.2412 - val_loss: 0.2916
# Epoch 79/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2406 - val_loss: 0.2919
# Epoch 80/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2399 - val_loss: 0.2913
# Epoch 81/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2401 - val_loss: 0.2915
# Epoch 82/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2395 - val_loss: 0.2917
# Epoch 83/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2397 - val_loss: 0.2914
# Epoch 84/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2391 - val_loss: 0.2914
# Epoch 85/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2391 - val_loss: 0.2911
# Epoch 86/100
# 184/184 [==============================] - 0s 2ms/step - loss: 0.2386 - val_loss: 0.2910
# Epoch 87/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2389 - val_loss: 0.2922
# Epoch 88/100
# 184/184 [==============================] - 0s 2ms/step - loss: 0.2384 - val_loss: 0.2908
# Epoch 89/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2384 - val_loss: 0.2904
# Epoch 90/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2385 - val_loss: 0.2919
# Epoch 91/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2383 - val_loss: 0.2903
# Epoch 92/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2381 - val_loss: 0.2906
# Epoch 93/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2376 - val_loss: 0.2900
# Epoch 94/100
# 184/184 [==============================] - 0s 2ms/step - loss: 0.2379 - val_loss: 0.2899
# Epoch 95/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2372 - val_loss: 0.2904
# Epoch 96/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2372 - val_loss: 0.2902
# Epoch 97/100
# 184/184 [==============================] - 0s 1ms/step - loss: 0.2373 - val_loss: 0.2902
# Epoch 98/100
# 145/184 [======================>.......] - ETA: 0s - loss: 0.2337Restoring model weights from the end of the best epoch: 93.
# 184/184 [==============================] - 0s 2ms/step - loss: 0.2367 - val_loss: 0.2902
# Epoch 98: early stopping
# INFO:tensorflow:Assets written to: /workspaces/credit-mlops/models/autoencoder.pkl/assets
# INFO:tensorflow:Assets written to: /workspaces/credit-mlops/models/autoencoder.pkl/assets

# %% [markdown]
# ### Apply the encoder model to get the reduced dimension

# %%
# Get the encoder model
encoder_model = Model(inputs=autoencoder.input, outputs=autoencoder.get_layer(index=1).output)

# Get the reduced data using the encoder
reduced_data = encoder_model.predict(df)

# Convert the reduced data to a DataFrame
reduced_df = pd.DataFrame(reduced_data, columns=[f"latent_{i+1}" for i in range(encoding_dim)])

# Save the reduced dataset to a CSV file
reduced_df.to_csv(os.path.join(ROOT_DIR, 'data', 'processed', 'featurized_data.csv'), index=False)
# Out:
# 230/230 [==============================] - 0s 766us/step

# %%
# Check the shape of the reduced data
print(reduced_df.shape)
# Out:
# (7346, 10)
